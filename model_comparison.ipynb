# %%
import pandas as pd

lstm_metrics = pd.read_csv("results/lstm_metrics.csv")
xgb_metrics = pd.read_csv("results/xgboost_metrics.csv")

comparison = pd.concat(
    [lstm_metrics, xgb_metrics],
    ignore_index=True
)

comparison
