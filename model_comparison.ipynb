# %% [markdown]
# # Gold Return Model Comparison

# %% [markdown]
# ## 1. Setup and Load Results

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

RESULTS_DIR = Path("results")

# %% [markdown]
# ## 2. LSTM Results Summary

# %%
lstm_model_metrics = lstm_metrics[
    lstm_metrics["Model"].isin([
        "Baseline LSTM",
        "Tuned LSTM"
    ])
].reset_index(drop=True)

lstm_model_metrics
# Out:
#            Model       MAE       MSE      RMSE        R2  Directional_Accuracy
# 0  Baseline LSTM  0.009158  0.000174  0.013195  0.000614              0.557769
# 1     Tuned LSTM  0.009123  0.000174  0.013183  0.002461              0.564409

# %% [markdown]
# ## 3. XGBoost Results Summary

# %% [markdown]
# ## 4. Model Performance Comparison

# %% [markdown]
# ## 5. Feature Importance Analysis

# %% [markdown]
# ## 6. Research Question Analysis

# %% [markdown]
# ## 7. Overall Conclusion
